# %% [markdown]
# -sandbox
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://cdn2.hubspot.net/hubfs/438089/docs/training/dblearning-banner.png" alt="Databricks Learning" width="555" height="64">
# </div>

# %% [markdown]
# -sandbox
# &copy; 2018 Databricks, Inc. All rights reserved.<br/>

# %% [markdown]
# ### Challenges
# * Larger Data - 100s GB, TB, PB
# * Faster data and decisions - seconds, minutes, hours not days or weeks after it is created
# * Dashboards and and Reports - for the holiday season, promotional campaigns, track falling or rising trends
#
# ### Azure Databricks Solutions
# * Larger Data on Azure Blob Storage or Azure Data Lake
# * Serverless Databricks Clusters to query this data
# * Secure SQL endpoints for Spark Clusters and RBACs

# %% [markdown]
# ####Azure Databricks for Serverless SQL & BI Queries for Data at Scale
#
# ![arch](https://kpistoropen.blob.core.windows.net/collateral/roadshow/azure_roadshow_bi.png)

# %% [markdown]
# ##![Spark Logo Tiny](https://kpistoropen.blob.core.windows.net/collateral/roadshow/logo_spark_tiny.png)[Azure Databricks & Power BI Integration Docs](https://docs.azuredatabricks.net/user-guide/bi/power-bi.html)
